# %% [markdown]
# <figure>
#   <IMG SRC="Logo.png"  WIDTH=150 ALIGN="right">
# </figure>
#
# ## Projections of mean sea level and tides<br>
# ### Six Dutch stations
# <b>Prepared by: H.G. Voortman</b>

# %% [markdown]
# <figure>
#     <IMG SRC="https://www.python.org/static/community_logos/python-powered-w-200x80.png"  WIDTH=100 ALIGN="right">
# </figure>
#
# #### Description

# %% [markdown]
# #### References
# - Provided in report

# %% [markdown]
# #### Packages

# %%
# General packages
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3 as sq
import numpy as np
#import scipy.signal as signal
#import datetime as dt
import hvec_stat.general_fit as gf
#import hvec_stat.gof as gof
import hvec_stat.support as sup
import models as mdl
import sigfig as sf

# %%
# Settings
plt.rcParams['axes.grid'] = True
figsize = (20, 18)

# %% [markdown]
# #### Connect databases and import data

# %% [markdown]
# ##### Processed data Rijkswaterstaat

# %%
# Connect database
conn_str = os.getenv('DATAPATH') + 'RWS_processed.db'
cnxn = sq.connect(conn_str, detect_types = True)

# %%
pd.read_sql('SELECT * FROM sqlite_master', cnxn)
# Out:
#     type                      name  tbl_name  rootpage  \
# 0  table                  const_yr  const_yr         2
# 1  index  ix_const_yr_naam_level_1  const_yr         3
#
#                                                  sql
# 0  CREATE TABLE "const_yr" (\n"naam" TEXT,\n  "le...
# 1  CREATE INDEX "ix_const_yr_naam_level_1"ON "con...

# %%
# Read table with observed water levels; complete years only
sql = (
    "SELECT * "
    "FROM 'const_yr' "
    "WHERE naam IN ('Delfzijl', 'Harlingen', "
    "'Den Helder', 'IJmuiden',  "
    "'Hoek van Holland', 'Vlissingen') "
    "AND (count>650) "
#    "AND (set == 'Ftested3') "
)
df = pd.read_sql(sql, cnxn) #.groupby('YEAR').mean()

# %%
cnxn.close()

# %%
df.columns = df.columns.str.replace('_ampl', '')
df.columns
# Out:
# Index(['naam', 'level_1', 'z0', 'zmean', 'count', 'M2', 'S2', 'Rsq_adj',
#        'MHWS', 'MLWS', 'MHWN', 'MLWN', 'year', 'year_start', 'set', 'M4', 'O1',
#        'K2', 'K1', 'P1', 'N2', 'M6', 'MU2', 'L2', '2MS6', 'MS4', 'NU2', 'SA'],
#       dtype='object')

# %%
#df = df[np.abs(df['z0']) < 1e2]
#df = df[np.abs(df['M2']) < 1e2]
tsplit = 2021
df = df[df['year'].between(1945, tsplit)]

# %%
names = [
    'Delfzijl',
    'Harlingen',
    'Den Helder',
    'IJmuiden',
    'Hoek van Holland',
    'Vlissingen'
]

# %%
df = df[df['set'] == 'Ftested3']

# %% [markdown]
# #### Calibrate per model

# %%
param = pd.DataFrame(columns = [
    'name',
    'var',
    'model',
    'intercept',
    'slope',
    'acceleration',
    'A_885',
    'A_1861',
    'Rsqadj',
    'p-value'], dtype = float)

# %%
vars = ['z0', 'MHWS', 'MLWS']

# %%
tmp = pd.DataFrame(columns = ['name'])

namestore = []
varstore = []
modelstore = []
intercept = []
slope = []
Rsqadj = []
pvalue = []

for vr in vars:
    for nm in names:
        """
        if nm == 'Delfzijl':
            if vr != 'z0':
                continue
        """
        data = df[df['naam'] == nm]
        res = gf.fit_with_uncert(
            mdl.model1,
            data['year'],
            data[vr]
        )

        p = res[0]
        
        namestore.append(nm)
        varstore.append(vr)
        modelstore.append('Model 1')
        intercept.append(p[0])
        slope.append(p[1])
        Rsqadj.append(res[5])

        # F-test
        pvalue.append(
            sup.Ftest_classic_direct(
                mdl.model1, 
                data['year'], data[vr],
                method = 'Bence', alpha = 0.05)['p'])        


tmp['name'] = namestore
tmp['var'] = varstore
tmp['model'] = modelstore
tmp['intercept'] = intercept
tmp['slope'] = slope
tmp['Rsqadj'] = Rsqadj
tmp['p-value'] = pvalue

param = pd.concat([param, tmp])

# %%
param
# Out:
#                 name   var    model  intercept     slope  acceleration  A_885  \
# 0           Delfzijl    z0  Model 1   0.044153  0.002349           NaN    NaN
# 1          Harlingen    z0  Model 1   0.002755  0.001681           NaN    NaN
# 2         Den Helder    z0  Model 1  -0.050433  0.001633           NaN    NaN
# 3           IJmuiden    z0  Model 1  -0.016989  0.001610           NaN    NaN
# 4   Hoek van Holland    z0  Model 1   0.021268  0.002252           NaN    NaN
# 5         Vlissingen    z0  Model 1  -0.038328  0.001590           NaN    NaN
# 6           Delfzijl  MHWS  Model 1   1.667551  0.004960           NaN    NaN
# 7          Harlingen  MHWS  Model 1   1.021635  0.002514           NaN    NaN
# 8         Den Helder  MHWS  Model 1   0.762417  0.002189           NaN    NaN
# 9           IJmuiden  MHWS  Model 1   0.816513  0.001886           NaN    NaN
# 10  Hoek van Holland  MHWS  Model 1   0.987000  0.003043           NaN    NaN
# 11        Vlissingen  MHWS  Model 1   2.180929  0.002123           NaN    NaN
# 12          Delfzijl  MLWS  Model 1  -1.579245 -0.000262           NaN    NaN
# 13         Harlingen  MLWS  Model 1  -1.016125  0.000848           NaN    NaN
# 14        Den Helder  MLWS  Model 1  -0.863283  0.001077           NaN    NaN
# 15          IJmuiden  MLWS  Model 1  -0.850490  0.001335           NaN    NaN
# 16  Hoek van Holland  MLWS  Model 1  -0.944464  0.001460           NaN    NaN
# 17        Vlissingen  MLWS  Model 1  -2.257585  0.001057           NaN    NaN
#
#     A_1861    Rsqadj       p-value
# 0      NaN  0.696865  1.898048e-12
# 1      NaN  0.515447  8.181620e-09
# 2      NaN  0.541191  1.652660e-07
# 3      NaN  0.535129  2.208119e-06
# 4      NaN  0.706257  1.293392e-10
# 5      NaN  0.636268  1.553706e-08
# 6      NaN  0.841500  4.423367e-11
# 7      NaN  0.678642  8.711402e-15
# 8      NaN  0.618041  1.981216e-08
# 9      NaN  0.528380  3.969082e-07
# 10     NaN  0.756053  4.918448e-10
# 11     NaN  0.634805  5.469335e-08
# 12     NaN -0.098243  8.855455e-01
# 13     NaN  0.150441  2.556303e-02
# 14     NaN  0.283855  3.387974e-03
# 15     NaN  0.351716  4.678610e-03
# 16     NaN  0.436675  3.474701e-05
# 17     NaN  0.215707  5.697166e-02

# %%
tmp = pd.DataFrame(columns = ['name'])

namestore = []
varstore = []
modelstore = []
intercept = []
slope = []
acceleration = []
Rsqadj = []
pvalue = []

for vr in vars:
    for nm in names:
        """if nm == 'Delfzijl':
            if vr != 'z0':
                continue
        """

        data = df[df['naam'] == nm]
        res = gf.fit_with_uncert(
            mdl.model2,
            data['year'],
            data[vr]
        )

        p = res[0]

        namestore.append(nm)
        varstore.append(vr)
        modelstore.append('Model 2')
        intercept.append(p[0])
        slope.append(p[1])
        acceleration.append(p[2])
        Rsqadj.append(res[5])

        # F-test
        pvalue.append(
            sup.Ftest_reduced_direct(
                mdl.model2, mdl.model1, 
                data['year'], data[vr],
                method = 'Bence', alpha = 0.05)['p'])        

tmp['name'] = namestore
tmp['var'] = varstore
tmp['model'] = modelstore
tmp['intercept'] = intercept
tmp['slope'] = slope
tmp['acceleration'] = acceleration
tmp['Rsqadj'] = Rsqadj
tmp['p-value'] = pvalue

param = pd.concat([param, tmp])

# %%
tmp = pd.DataFrame(columns = ['name'])

namestore = []
varstore = []
modelstore = []
intercept = []
slope = []
acceleration = []
A_885 = []
A_1861 = []
Rsqadj = []
pvalue = []

for vr in vars:
    for nm in names:
        """
        if nm == 'Delfzijl':
            if vr != 'z0':
                continue
        """
        data = df[df['naam'] == nm]
        res = gf.fit_with_uncert(
            mdl.model3,
            data['year'],
            data[vr]
        )

        p = res[0]

        namestore.append(nm)
        varstore.append(vr)
        modelstore.append('Model 3')
        intercept.append(p[0])
        slope.append(p[1])
        #acceleration.append(p[2])
        A_885.append(np.sqrt(p[2] ** 2 + p[3] ** 2))
        A_1861.append(np.sqrt(p[4] ** 2 + p[5] ** 2))
        Rsqadj.append(res[5])

        # F-test
        pvalue.append(
            sup.Ftest_reduced_direct(
                mdl.model3, mdl.model1, 
                data['year'], data[vr],
                method = 'Bence', alpha = 0.05)['p'])
        

tmp['name'] = namestore
tmp['var'] = varstore
tmp['model'] = modelstore
tmp['intercept'] = intercept
tmp['slope'] = slope
#tmp['acceleration'] = acceleration
tmp['A_885'] = A_885
tmp['A_1861'] = A_1861
tmp['Rsqadj'] = Rsqadj
tmp['p-value'] = pvalue

param = pd.concat([param, tmp])

# %% [markdown]
# tmp = pd.DataFrame()
#
# namestore = []
# varstore = []
# modelstore = []
# intercept = []
# slope = []
# acceleration = []
# A_885 = []
# A_1861 = []
# Rsqadj = []
# pvalue = []
#
# for vr in vars:
#     for nm in names:
#         """
#         if nm == 'Delfzijl':
#             if vr != 'z0':
#                 continue
#         """
#         data = df[df['naam'] == nm]
#         res = gf.fit_with_uncert(
#             mdl.model4,
#             data['year'],
#             data[vr]
#         )
#
#         p = res[0]
#
#         namestore.append(nm)
#         varstore.append(vr)
#         modelstore.append('Model 4')
#         intercept.append(p[0])
#         slope.append(p[1])
#         acceleration.append(p[2])
#         A_885.append(np.sqrt(p[2] ** 2 + p[3] ** 2))
#         A_1861.append(np.sqrt(p[4] ** 2 + p[5] ** 2))
#         Rsqadj.append(res[5])
#
#         # F-test
#         pvalue.append(
#             sup.Ftest_reduced_direct(
#                 mdl.model4, mdl.model1,
#                 data['year'], data[vr],
#                 method = 'Bence', alpha = 0.05)['p'])
#
#
# tmp['name'] = namestore
# tmp['var'] = varstore
# tmp['model'] = modelstore
# tmp['intercept'] = intercept
# tmp['slope'] = slope
# tmp['acceleration'] = acceleration
# tmp['A_885'] = A_885
# tmp['A_1861'] = A_1861
# tmp['Rsqadj'] = Rsqadj
# tmp['p-value'] = pvalue
#
# param = pd.concat([param, tmp])

# %%
param.loc[param['var'] == 'z0', ['name', 'model', 'slope', 'acceleration', 'A_885', 'A_1861']].to_excel(r'../Data/empirical.xlsx')

# %%
# Set units (length mm and time centuries) for publication table
param['intercept'] = (1000 * param['intercept']).round()
param['slope'] = (1e5 * param['slope']).round()
param['acceleration'] = (1e7 * param['acceleration']).round()
param['A_885'] = (1e3 * param['A_885']).round()
param['A_1861'] = (1e3 * param['A_1861']).round()
param['Rsqadj'] = (1e2 * param['Rsqadj']).round()
param['p-value'] = (1e2 * param['p-value']).apply(lambda x: sf.round(x, 2))

# %%
def func(x):
    if x < 1:
        return '< 1'
    if x < 5:
        return '> 1 and < 5'
    return round(x, 0)

# %%
param['p-value'] = param['p-value'].apply(lambda x: func(x))

# %%
param.sort_values(by = ['name', 'model'], inplace = True)

# %%
param
# Out:
#           name   var    model  intercept  slope  acceleration  A_885  A_1861  \
# 0     Delfzijl    z0  Model 1       44.0  235.0           NaN    NaN     NaN
# 6     Delfzijl  MHWS  Model 1     1668.0  496.0           NaN    NaN     NaN
# 12    Delfzijl  MLWS  Model 1    -1579.0  -26.0           NaN    NaN     NaN
# 0     Delfzijl    z0  Model 2       35.0  235.0         189.0    NaN     NaN
# 6     Delfzijl  MHWS  Model 2     1681.0  496.0        -282.0    NaN     NaN
# ..         ...   ...      ...        ...    ...           ...    ...     ...
# 11  Vlissingen  MHWS  Model 3     2181.0  205.0           NaN    7.0    16.0
# 17  Vlissingen  MLWS  Model 3    -2258.0  120.0           NaN    3.0    32.0
# 5   Vlissingen    z0  Model 4      -43.0  162.0          87.0    5.0    13.0
# 11  Vlissingen  MHWS  Model 4     2190.0  205.0        -192.0    6.0    11.0
# 17  Vlissingen  MLWS  Model 4    -2276.0  120.0         366.0    4.0    14.0
#
#     Rsqadj p-value
# 0     70.0     < 1
# 6     84.0     < 1
# 12   -10.0    89.0
# 0     71.0     8.0
# 6     85.0    15.0
# ..     ...     ...
# 11    65.0    31.0
# 17    48.0     < 1
# 5     69.0     6.0
# 11    67.0    15.0
# 17    68.0     < 1
#
# [72 rows x 10 columns]

# %%
param[param['var'] == 'z0'].drop(['var', 'intercept'], axis = 1).to_excel(r'../results/fitted_models_z0.xlsx', index = False)
param[param['var'] == 'MHWS'].drop(['var', 'intercept'], axis = 1).to_excel(r'../results/fitted_models_MHWS.xlsx', index = False)
param[param['var'] == 'MLWS'].drop(['var', 'intercept'], axis = 1).to_excel(r'../results/fitted_models_MLWS.xlsx', index = False)

# %% [markdown]
# #### End script
# Prepared by HVEC lab, 2022
