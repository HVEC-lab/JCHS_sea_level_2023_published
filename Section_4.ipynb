# %% [markdown]
# <figure>
#   <IMG SRC="Logo.png"  WIDTH=150 ALIGN="right">
# </figure>
#
# ## Projections of mean sea level and tides<br>
# ### Paper in Journal of Coastal and Hydraulic Structures
# <b>Prepared by: H.G. Voortman</b>

# %% [markdown]
# <figure>
#     <IMG SRC="https://www.python.org/static/community_logos/python-powered-w-200x80.png"  WIDTH=100 ALIGN="right">
# </figure>
#
# #### Description
# - Analyses described in section 4 of the paper

# %% [markdown]
# #### Packages

# %%
# General packages
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3 as sq
import numpy as np
import scipy.signal as signal
import datetime as dt

# Project package
import utils as prj

# %% [markdown]
# #### Connect databases and import data

# %%
df = prj.read_data_rws(constit_set = 'PE')

# %%
df
# Out:
#            naam  level_1        z0     zmean    count        M2        S2
# 0      Delfzijl        0 -0.232430 -0.227556   1019.0  1.433311  0.154408  \
# 1      Delfzijl        0 -0.195779 -0.205129   4184.0  1.367969  0.304330
# 2      Delfzijl        0 -0.146369 -0.151690   4236.0  1.365113  0.315767
# 3      Delfzijl        0 -0.185528 -0.200764   4164.0  1.376014  0.283047
# 4      Delfzijl        0 -0.167087 -0.172632   4285.0  1.412886  0.320259
# ..          ...      ...       ...       ...      ...       ...       ...
# 860  Vlissingen        0  0.031208  0.046079   8760.0  1.771234  0.464153
# 861  Vlissingen        0 -0.005708  0.000808   8760.0  1.786233  0.462828
# 862  Vlissingen        0  0.044007  0.050753   8760.0  1.748527  0.461571
# 863  Vlissingen        0  0.040856  0.058649   8784.0  1.763642  0.463379
# 864  Vlissingen        0  0.044464  0.054976  12584.0  1.742397  0.453133
#
#            M4        O1       MS4  ...      smax   Rsq_adj      MHWS
# 0    0.064756  0.064130  0.055765  ...  2.721642  0.925755  1.355288  \
# 1    0.144026  0.087998  0.063212  ...  1.944423  0.835961  1.476519
# 2    0.155903  0.080742  0.081108  ...  2.458095  0.850289  1.534511
# 3    0.142016  0.082427  0.068983  ...  3.868533  0.807126  1.473533
# 4    0.178268  0.085267  0.086635  ...  2.290040  0.827746  1.566057
# ..        ...       ...       ...  ...       ...       ...       ...
# 860  0.125387  0.089540  0.075327  ...  2.347168  0.937503  2.266595
# 861  0.131358  0.103494  0.076674  ...  1.433112  0.936852  2.243353
# 862  0.120275  0.099193  0.071782  ...  1.849021  0.938406  2.254106
# 863  0.128753  0.101863  0.068698  ...  1.966732  0.931254  2.267877
# 864  0.122717  0.115299  0.069484  ...  1.632566  0.938332  2.239995
#
#          MLWS      MHWN      MLWN  year  year_start  const_set     M2+S2
# 0   -1.820149  1.046472 -1.511333  1878        1878         PE  1.587719
# 1   -1.868077  0.867860 -1.259418  1879        1879         PE  1.672298
# 2   -1.827248  0.902977 -1.195715  1880        1880         PE  1.680879
# 3   -1.844589  0.907438 -1.278494  1881        1881         PE  1.659061
# 4   -1.900232  0.925539 -1.259714  1882        1882         PE  1.733144
# ..        ...       ...       ...   ...         ...        ...       ...
# 860 -2.204179  1.338289 -1.275873  2017        2017         PE  2.235387
# 861 -2.254769  1.317697 -1.329113  2018        2018         PE  2.249061
# 862 -2.166091  1.330963 -1.242949  2019        2019         PE  2.210099
# 863 -2.186165  1.341118 -1.259407  2020        2020         PE  2.227021
# 864 -2.151066  1.333729 -1.244800  2021        2021         PE  2.195530
#
# [865 rows x 24 columns]

# %% [markdown]
# ##### Data PSMSL

# %%
psmsl = prj.read_data_psmsl()

# %%
psmsl
# Out:
#            name  time  level type    freq
# 0      DELFZIJL  1865  6.653  rlr  annual
# 1      DELFZIJL  1866  6.746  rlr  annual
# 2      DELFZIJL  1867  6.769  rlr  annual
# 3      DELFZIJL  1868  6.735  rlr  annual
# 4      DELFZIJL  1869  6.752  rlr  annual
# ..          ...   ...    ...  ...     ...
# 934  VLISSINGEN  2017  6.976  rlr  annual
# 935  VLISSINGEN  2018  6.931  rlr  annual
# 936  VLISSINGEN  2019  6.981  rlr  annual
# 937  VLISSINGEN  2020  6.988  rlr  annual
# 938  VLISSINGEN  2021  6.976  rlr  annual
#
# [939 rows x 5 columns]

# %%
prj.graph_Rsqadj(df)

# %%
prj.graph_z0(df, psmsl)

# %% [markdown]
# #### Tides

# %%
prj.graph_amplitudes(df)
# Out:
# s:\JCHS_sea_level\utils.py:221: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:221: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:221: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:221: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:221: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:221: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]

# %% [markdown]
# #### End script
# Prepared by HVEC lab, 2022
