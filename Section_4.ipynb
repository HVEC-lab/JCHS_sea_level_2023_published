# %% [markdown]
# <figure>
#   <IMG SRC="Logo.png"  WIDTH=150 ALIGN="right">
# </figure>
#
# ## Projections of mean sea level and tides<br>
# ### Paper in Journal of Coastal and Hydraulic Structures
# <b>Prepared by: H.G. Voortman</b>

# %% [markdown]
# <figure>
#     <IMG SRC="https://www.python.org/static/community_logos/python-powered-w-200x80.png"  WIDTH=100 ALIGN="right">
# </figure>
#
# #### Description
# - Analyses described in section 4 of the paper

# %% [markdown]
# #### Packages

# %%
# General packages
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3 as sq
import numpy as np
import scipy.signal as signal
import datetime as dt

# Project package
import utils as prj

# %% [markdown]
# #### Connect databases and import data

# %%
df = prj.read_data_rws(constit_set = 'PE')

# %%
df
# Out:
#             naam  level_1        z0     zmean    count        M2        S2
# 1152    Delfzijl        0 -0.232430 -0.227556   1019.0  1.433311  0.154408  \
# 1153    Delfzijl        0 -0.195779 -0.205129   4184.0  1.367969  0.304330
# 1154    Delfzijl        0 -0.146369 -0.151690   4236.0  1.365113  0.315767
# 1155    Delfzijl        0 -0.185528 -0.200764   4164.0  1.376014  0.283047
# 1156    Delfzijl        0 -0.167087 -0.172632   4285.0  1.412886  0.320259
# ...          ...      ...       ...       ...      ...       ...       ...
# 7888  Vlissingen        0  0.031208  0.046079   8760.0  1.771234  0.464153
# 7889  Vlissingen        0 -0.005708  0.000808   8760.0  1.786233  0.462828
# 7890  Vlissingen        0  0.044007  0.050753   8760.0  1.748527  0.461571
# 7891  Vlissingen        0  0.040856  0.058649   8784.0  1.763642  0.463379
# 7892  Vlissingen        0  0.044464  0.054976  12584.0  1.742397  0.453133
#
#          smean      smin      smax  ...  P1        N2  M6  MU2  L2  2MS6
# 1152  0.032788 -1.429497  2.721642  ... NaN  0.007661 NaN  NaN NaN   NaN  \
# 1153  0.000573 -2.740408  1.944423  ... NaN  0.177131 NaN  NaN NaN   NaN
# 1154  0.015671 -2.230859  2.458095  ... NaN  0.162854 NaN  NaN NaN   NaN
# 1155  0.003060 -2.888295  3.868533  ... NaN  0.167213 NaN  NaN NaN   NaN
# 1156  0.012561 -2.593033  2.290040  ... NaN  0.191881 NaN  NaN NaN   NaN
# ...        ...       ...       ...  ...  ..       ...  ..  ...  ..   ...
# 7888  0.014713 -1.267753  2.347168  ... NaN  0.285795 NaN  NaN NaN   NaN
# 7889  0.005978 -1.533792  1.433112  ... NaN  0.262831 NaN  NaN NaN   NaN
# 7890  0.007092 -1.334088  1.849021  ... NaN  0.281222 NaN  NaN NaN   NaN
# 7891  0.018144 -1.385076  1.966732  ... NaN  0.289820 NaN  NaN NaN   NaN
# 7892  0.006079 -1.508283  1.632566  ... NaN  0.248838 NaN  NaN NaN   NaN
#
#            MS4 NU2        SA     M2+S2
# 1152  0.055765 NaN  0.012148  1.587719
# 1153  0.063212 NaN  0.104204  1.672298
# 1154  0.081108 NaN  0.113565  1.680879
# 1155  0.068983 NaN  0.083500  1.659061
# 1156  0.086635 NaN  0.029287  1.733144
# ...        ...  ..       ...       ...
# 7888  0.075327 NaN  0.095467  2.235387
# 7889  0.076674 NaN  0.065610  2.249061
# 7890  0.071782 NaN  0.080609  2.210099
# 7891  0.068698 NaN  0.057890  2.227021
# 7892  0.069484 NaN  0.065852  2.195530
#
# [877 rows x 32 columns]

# %% [markdown]
# ##### Data PSMSL

# %%
psmsl = prj.read_data_psmsl()

# %%
psmsl
# Out:
#            name  time  level type    freq
# 0      DELFZIJL  1865  6.653  rlr  annual
# 1      DELFZIJL  1866  6.746  rlr  annual
# 2      DELFZIJL  1867  6.769  rlr  annual
# 3      DELFZIJL  1868  6.735  rlr  annual
# 4      DELFZIJL  1869  6.752  rlr  annual
# ..          ...   ...    ...  ...     ...
# 934  VLISSINGEN  2017  6.976  rlr  annual
# 935  VLISSINGEN  2018  6.931  rlr  annual
# 936  VLISSINGEN  2019  6.981  rlr  annual
# 937  VLISSINGEN  2020  6.988  rlr  annual
# 938  VLISSINGEN  2021  6.976  rlr  annual
#
# [939 rows x 5 columns]

# %%
prj.graph_Rsqadj(df)

# %%
prj.graph_z0(df, psmsl)

# %% [markdown]
# #### Tides

# %%
prj.graph_amplitudes(df)
# Out:
# s:\JCHS_sea_level\utils.py:222: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:222: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:222: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:222: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:222: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:222: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]

# %%
prj.graph_windeffect(df)
# Out:
# s:\JCHS_sea_level\utils.py:274: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:274: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:274: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:274: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:274: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]
# s:\JCHS_sea_level\utils.py:274: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]

# %% [markdown]
# #### End script
# Prepared by HVEC lab, 2022
