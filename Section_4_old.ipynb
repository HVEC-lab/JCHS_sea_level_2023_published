# %% [markdown]
# <figure>
#   <IMG SRC="Logo.png"  WIDTH=150 ALIGN="right">
# </figure>
#
# ## Projections of mean sea level and tides<br>
# ### Paper in Journal of Coastal and Hydraulic Structures
# <b>Prepared by: H.G. Voortman</b>

# %% [markdown]
# <figure>
#     <IMG SRC="https://www.python.org/static/community_logos/python-powered-w-200x80.png"  WIDTH=100 ALIGN="right">
# </figure>
#
# #### Description
# - Analyses described in section 4 of the paper

# %% [markdown]
# #### Packages

# %%
# General packages
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3 as sq
import numpy as np
import scipy.signal as signal
import datetime as dt

# Project package
import utils as prj

# %% [markdown]
# #### Connect databases and import data

# %%
df = prj.read_data_rws(constit_set = 'Ftested3')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Hessel Voortman\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File c:\Users\Hessel Voortman\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Hessel Voortman\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'set'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = prj.read_data_rws(constit_set = 'Ftested3')
#
# File c:\Users\Hessel Voortman\OneDrive - Hessel Voortman EC BV\20 Werk\2022_014 - papers sea level and tide\JCHS_sea_level_North_Sea\utils.py:56, in read_data_rws(constit_set)
#      52 cnxn.close()
#      54 df.columns = df.columns.str.replace('_ampl', '')
# ---> 56 df = df[df['set'] == constit_set]
#      58 df = df[df['year'] < 2022]
#      60 df['M2+S2'] = df['M2'] + df['S2']
#
# File c:\Users\Hessel Voortman\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File c:\Users\Hessel Voortman\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'set'

# %% [markdown]
# ##### Data PSMSL

# %%
psmsl = prj.read_data_psmsl()

# %%
psmsl
# Out:
#            name  time  level type    freq
# 0      DELFZIJL  1865  6.653  rlr  annual
# 1      DELFZIJL  1866  6.746  rlr  annual
# 2      DELFZIJL  1867  6.769  rlr  annual
# 3      DELFZIJL  1868  6.735  rlr  annual
# 4      DELFZIJL  1869  6.752  rlr  annual
# ..          ...   ...    ...  ...     ...
# 934  VLISSINGEN  2017  6.976  rlr  annual
# 935  VLISSINGEN  2018  6.931  rlr  annual
# 936  VLISSINGEN  2019  6.981  rlr  annual
# 937  VLISSINGEN  2020  6.988  rlr  annual
# 938  VLISSINGEN  2021  6.976  rlr  annual
#
# [939 rows x 5 columns]

# %%
prj.graph_Rsqadj(df)

# %%
prj.graph_z0(df, psmsl)

# %% [markdown]
# #### Tides

# %%
prj.graph_amplitudes(df)
# Out:
# c:\Users\Hessel Voortman\OneDrive - Hessel Voortman EC BV\20 Werk\2022_014 - papers sea level and tide\JCHS_sea_level_North_Sea\utils.py:221: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data[df['count'] < Nmn]

# %% [markdown]
# #### End script
# Prepared by HVEC lab, 2022
