# %% [markdown]
# <figure>
#   <IMG SRC="Logo.png"  WIDTH=150 ALIGN="right">
# </figure>
#
# ## Projections of mean sea level and tides<br>
# ### Paper in Journal of Coastal and Hydraulic Structures
# <b>Prepared by: H.G. Voortman</b>

# %% [markdown]
# <figure>
#     <IMG SRC="https://www.python.org/static/community_logos/python-powered-w-200x80.png"  WIDTH=100 ALIGN="right">
# </figure>
#
# #### Description
# - Analyses described in section 3 of the paper

# %% [markdown]
# #### Packages

# %%
# General packages
import os
import copy as cp
import sqlite3 as sq
import pandas as pd
import numpy as np
import hvec_tide as tide
from matplotlib import pyplot as plt

# Company packages
from hvec_support import sqlite as hvsq
import hvec_tide as tide

# Project package
from utils import names
# Out:
# s:\JCHS_sea_level\.venv\Lib\site-packages\utide\harmonics.py:16: RuntimeWarning: invalid value encountered in cast
#   nshallow = np.ma.masked_invalid(const.nshallow).astype(int)
# s:\JCHS_sea_level\.venv\Lib\site-packages\utide\harmonics.py:17: RuntimeWarning: invalid value encountered in cast
#   ishallow = np.ma.masked_invalid(const.ishallow).astype(int) - 1

# %%
tide.__version__
# Out:
# '3.4.0'

# %% [markdown]
# #### Import data

# %%
os.chdir(os.getenv('DATAPATH'))
cnxn = hvsq.connect_verbose(r'RWS_data.db', detect_types = True)
# Out:
# The database  RWS_data.db  is opened.
# This database contains the following tables:
#                  name
# 0       RWS_Waterinfo
# 1  Logboek_databeheer
# 2        Download_log
# 3                 log
# 4            stations
# 5                data

# %%
sql = (
    'SELECT * FROM RWS_Waterinfo WHERE '
    'naam IN ("Harlingen", "Hoek van Holland", "IJmuiden Noordersluis", "Den Helder", "Harlingen", "Delfzijl", "Vlissingen") '
    )
df = pd.read_sql(sql, cnxn)

# %%
df['year'] = pd.to_datetime(df['tijd']).dt.year

# %%
df
# Out:
#          level_0  index        naam  code                tijd  waarde
# 0            0.0    0.0  Vlissingen  VLIS 2021-12-25 06:00:00   139.0  \
# 1            1.0    6.0  Vlissingen  VLIS 2021-12-25 07:00:00    77.0
# 2            2.0   12.0  Vlissingen  VLIS 2021-12-25 08:00:00   -11.0
# 3            3.0   18.0  Vlissingen  VLIS 2021-12-25 09:00:00   -96.0
# 4            4.0   24.0  Vlissingen  VLIS 2021-12-25 10:00:00  -157.0
# ...          ...    ...         ...   ...                 ...     ...
# 4049584      NaN    NaN  Vlissingen  None 1899-12-30 19:00:00  -183.0
# 4049585      NaN    NaN  Vlissingen  None 1899-12-31 00:30:00   171.0
# 4049586      NaN    NaN  Vlissingen  None 1899-12-31 07:25:00  -198.0
# 4049587      NaN    NaN  Vlissingen  None 1899-12-31 12:55:00   175.0
# 4049588      NaN    NaN  Vlissingen  None 1899-12-31 19:40:00  -218.0
#
#         grootheid     eenheid           kwalico      statuswaarde
# 0          WATHTE  centimeter                00   Ongecontroleerd  \
# 1          WATHTE  centimeter                00   Ongecontroleerd
# 2          WATHTE  centimeter                00   Ongecontroleerd
# 3          WATHTE  centimeter                00   Ongecontroleerd
# 4          WATHTE  centimeter                00   Ongecontroleerd
# ...           ...         ...               ...               ...
# 4049584    WATHTE          cm  Historische data  Niet beschikbaar
# 4049585    WATHTE          cm  Historische data  Niet beschikbaar
# 4049586    WATHTE          cm  Historische data  Niet beschikbaar
# 4049587    WATHTE          cm  Historische data  Niet beschikbaar
# 4049588    WATHTE          cm  Historische data  Niet beschikbaar
#
#                  bemonsteringsapparaat meetapparaat
# 0        Waarde is niet van toepassing      Vlotter  \
# 1        Waarde is niet van toepassing      Vlotter
# 2        Waarde is niet van toepassing      Vlotter
# 3        Waarde is niet van toepassing      Vlotter
# 4        Waarde is niet van toepassing      Vlotter
# ...                                ...          ...
# 4049584                            999          999
# 4049585                            999          999
# 4049586                            999          999
# 4049587                            999          999
# 4049588                            999          999
#
#                                                       bron       datum  year
# 0                           Download via API with HVEC_PC2  2022-05-03  2021  \
# 1                           Download via API with HVEC_PC2  2022-05-03  2021
# 2                           Download via API with HVEC_PC2  2022-05-03  2021
# 3                           Download via API with HVEC_PC2  2022-05-03  2021
# 4                           Download via API with HVEC_PC2  2022-05-03  2021
# ...                                                    ...         ...   ...
# 4049584  Historische waterstandsdata. Verkregen van RWS...        None  1899
# 4049585  Historische waterstandsdata. Verkregen van RWS...        None  1899
# 4049586  Historische waterstandsdata. Verkregen van RWS...        None  1899
# 4049587  Historische waterstandsdata. Verkregen van RWS...        None  1899
# 4049588  Historische waterstandsdata. Verkregen van RWS...        None  1899
#
#             tepoch_dy
# 0        18986.250000
# 1        18986.291667
# 2        18986.333333
# 3        18986.375000
# 4        18986.416667
# ...               ...
# 4049584 -25568.208333
# 4049585 -25567.979167
# 4049586 -25567.690972
# 4049587 -25567.461806
# 4049588 -25567.180556
#
# [4049589 rows x 16 columns]

# %%
res = df[['naam', 'year']].groupby('naam').min()

# %%
res['total_years'] = 2022 - res['year']

# %%
res
# Out:
#                        year  total_years
# naam
# Delfzijl               1878          144
# Den Helder             1851          171
# Harlingen              1876          146
# Hoek van Holland       1887          135
# IJmuiden Noordersluis  1883          139
# Vlissingen             1863          159

# %%
res['total_years'].sum()
# Out:
# 894

# %% [markdown]
# #### End script
# Prepared by HVEC lab, 2022
